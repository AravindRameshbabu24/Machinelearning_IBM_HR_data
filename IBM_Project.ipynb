# %%
#Importing the neccessary libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import datetime as dt
from pandas import DataFrame
plt.rcParams['figure.figsize'] = (16,10)

# %%
#Importing the data 
data = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  ...  YearsInCurrentRole YearsSinceLastPromotion  YearsWithCurrManager
# 0   41       Yes      Travel_Rarely  ...                   4                       0                     5
# 1   49        No  Travel_Frequently  ...                   7                       1                     7
# 2   37       Yes      Travel_Rarely  ...                   0                       0                     0
# 3   33        No  Travel_Frequently  ...                   7                       3                     0
# 4   27        No      Travel_Rarely  ...                   2                       2                     2
#
# [5 rows x 35 columns]

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data.shape
# Out:
# (1470, 35)

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome  ...  YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# count  1470.000000  1470.000000       1470.000000  ...         1470.000000              1470.000000           1470.000000
# mean     36.923810   802.485714          9.192517  ...            4.229252                 2.187755              4.123129
# std       9.135373   403.509100          8.106864  ...            3.623137                 3.222430              3.568136
# min      18.000000   102.000000          1.000000  ...            0.000000                 0.000000              0.000000
# 25%      30.000000   465.000000          2.000000  ...            2.000000                 0.000000              2.000000
# 50%      36.000000   802.000000          7.000000  ...            3.000000                 1.000000              3.000000
# 75%      43.000000  1157.000000         14.000000  ...            7.000000                 3.000000              7.000000
# ...

# %% [markdown]
# EmployeeCount: Dropped
#
# EmployeeNumber:Dropped
#
# StandardHours:Dropped

# %%
num_col =list(data.describe().columns)
column_categorical = list(set(data.columns).difference(num_col))
Remove_list = ['EmployeeCount','EmployeeNumber','StandardHours']
column_categorical = [i for i in num_col if i not in Remove_list]

# %%
num_col
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'Education',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
cate = []
for i , v in data.iteritems():
    if v.dtype == 'object':
        cate.append(i)
print(cate)
# Out:
# ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']

# %%
plt.figure(figsize=(24,8))
sns.heatmap(data=data.corr(),annot=True)
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  ...  YearsInCurrentRole YearsSinceLastPromotion  YearsWithCurrManager
# 0   41       Yes      Travel_Rarely  ...                   4                       0                     5
# 1   49        No  Travel_Frequently  ...                   7                       1                     7
# 2   37       Yes      Travel_Rarely  ...                   0                       0                     0
# 3   33        No  Travel_Frequently  ...                   7                       3                     0
# 4   27        No      Travel_Rarely  ...                   2                       2                     2
#
# [5 rows x 35 columns]

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
numerical_column = list(data.describe().columns)
categorical_column =list(set(data.columns.difference(numerical_column)))

# %%
categorical_column
# Out:
# ['Gender',
#  'EducationField',
#  'MaritalStatus',
#  'OverTime',
#  'Department',
#  'BusinessTravel',
#  'JobRole',
#  'Over18',
#  'Attrition']

# %%
Remove_list = ['EmployeeCount','EmployeeNumber','StandardHours']

# %%
data = data.drop(('EmployeeCount'),axis=1)
data = data.drop(('EmployeeNumber'),axis=1)
data = data.drop(('StandardHours'),axis=1)

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  ...  YearsInCurrentRole YearsSinceLastPromotion  YearsWithCurrManager
# 0   41       Yes      Travel_Rarely  ...                   4                       0                     5
# 1   49        No  Travel_Frequently  ...                   7                       1                     7
# 2   37       Yes      Travel_Rarely  ...                   0                       0                     0
# 3   33        No  Travel_Frequently  ...                   7                       3                     0
# 4   27        No      Travel_Rarely  ...                   2                       2                     2
#
# [5 rows x 32 columns]

# %%
categorical_column
# Out:
# ['Gender',
#  'EducationField',
#  'MaritalStatus',
#  'OverTime',
#  'Department',
#  'BusinessTravel',
#  'JobRole',
#  'Over18',
#  'Attrition']

# %%
#Data preprocessing 
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
data.Gender = label.fit_transform(data.Gender)
data.EducationField = label.fit_transform(data.EducationField)
data.MaritalStatus = label.fit_transform(data.MaritalStatus)
data.OverTime = label.fit_transform(data.OverTime)
data.Department = label.fit_transform(data.Department)
data.BusinessTravel = label.fit_transform(data.BusinessTravel)
data.JobRole = label.fit_transform(data.JobRole)
data.Over18 = label.fit_transform(data.Over18)
data.Attrition = label.fit_transform(data.Attrition)

# %%
data.head()
# Out:
#    Age  Attrition  BusinessTravel  ...  YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0   41          1               2  ...                   4                        0                     5
# 1   49          0               1  ...                   7                        1                     7
# 2   37          1               2  ...                   0                        0                     0
# 3   33          0               1  ...                   7                        3                     0
# 4   27          0               2  ...                   2                        2                     2
#
# [5 rows x 32 columns]

# %%
data.corr()
# Out:
#                                Age  Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# Age                       1.000000  -0.159205  ...                 0.216513              0.202089
# Attrition                -0.159205   1.000000  ...                -0.033019             -0.156199
# BusinessTravel            0.024751   0.000074  ...                -0.032591             -0.022636
# DailyRate                 0.010661  -0.056652  ...                -0.033229             -0.026363
# Department               -0.031882   0.063991  ...                 0.040061              0.034282
# DistanceFromHome         -0.001686   0.077924  ...                 0.010029              0.014406
# Education                 0.208034  -0.031373  ...                 0.054254              0.069065
# EducationField           -0.040873   0.026846  ...                 0.002326             -0.004130
# EnvironmentSatisfaction   0.010146  -0.103369  ...                 0.016194             -0.004999
# ...

# %%
X  = data.drop(('Attrition'),axis=1)
Y = data['Attrition']

# %%
#Modelling
from sklearn.model_selection import train_test_split
X_train, X_test , Y_train , Y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
#Feature Scaling 
from sklearn.preprocessing import StandardScaler
Std = StandardScaler()

# %%
X_train = Std.fit_transform(X_train)
X_test = Std.transform(X_test)

# %%
#Applying the Classification models on our data 
def model(X_train ,Y_train):
    
    #Logistic Regression 
    from sklearn.linear_model import LogisticRegression
    Log = LogisticRegression(random_state=0,solver='lbfgs')
    Log.fit(X_train,Y_train)
    
    #SGD Classification
    from sklearn.linear_model import SGDClassifier
    SGD = SGDClassifier(random_state=0)
    SGD.fit(X_train,Y_train)
    
    #Decision Tree Classification
    from sklearn.tree import DecisionTreeClassifier
    tree = DecisionTreeClassifier(random_state=0)
    tree.fit(X_train,Y_train)
    
    #Random Forest Classification
    from sklearn.ensemble import RandomForestClassifier
    Forest = RandomForestClassifier(random_state=0 )
    Forest.fit(X_train,Y_train)
    
    #Ada Boost Classification 
    from sklearn.ensemble import AdaBoostClassifier
    Ada = AdaBoostClassifier(random_state=0)
    Ada.fit(X_train,Y_train)
    
    #K_nearest Neighbour Classification
    from sklearn.neighbors import KNeighborsClassifier
    Knn = KNeighborsClassifier(n_neighbors=3)
    Knn.fit(X_train,Y_train)
    
    #Support Vector Machine Classification
    from sklearn.svm import SVC
    SVM = SVC(gamma='scale')
    SVM.fit(X_train,Y_train)
    
    #Naives Bayes Classification
    from sklearn.naive_bayes import GaussianNB
    Nb = GaussianNB()
    Nb.fit(X_train,Y_train)
    
    # Printing the Scores of Respective Models 
    print('[0] Logistic Regression ',Log.score(X_train,Y_train))
    print('[1] SGD Classification ',SGD.score(X_train,Y_train))
    print('[2] Decision Tree Classification ',tree.score(X_train,Y_train))
    print('[3] Random Forest Classification ',Forest.score(X_train,Y_train))
    print('[4] Ada Boost Classification ',Ada.score(X_train,Y_train))
    print('[5] K_Nearest_Neighbour Classification ',Knn.score(X_train,Y_train))
    print('[6] Support_Vector_Machine Classification ',SVM.score(X_train,Y_train))
    print('[7] Naives_Bayes_Classification ',Nb.score(X_train,Y_train))
    
    
    return Log , SGD , tree , Forest , Ada , Knn , SVM , Nb

# %%
Models = model(X_train,Y_train)
# Out:
# [0] Logistic Regression  0.875
# [1] SGD Classification  0.8180272108843537
# [2] Decision Tree Classification  1.0
# [3] Random Forest Classification  1.0
# [4] Ada Boost Classification  0.907312925170068
# [5] K_Nearest_Neighbour Classification  0.8920068027210885
# [6] Support_Vector_Machine Classification  0.9115646258503401
# [7] Naives_Bayes_Classification  0.7797619047619048

# %%
Y_prediction = Models[4].predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(Y_test,Y_prediction))
# Out:
# 0.8503401360544217

# %%
def Score(X_train,Y_train):
     #Logistic Regression 
    from sklearn.linear_model import LogisticRegression
    Log = LogisticRegression(random_state=0,solver='lbfgs')
    Log.fit(X_train,Y_train)
    
     #SGD Classification
    from sklearn.linear_model import SGDClassifier
    SGD = SGDClassifier(random_state=0)
    SGD.fit(X_train,Y_train)
    
    #Decision Tree Classification
    from sklearn.tree import DecisionTreeClassifier
    tree = DecisionTreeClassifier(random_state=0)
    tree.fit(X_train,Y_train)
    
    #Random Forest Classification
    from sklearn.ensemble import RandomForestClassifier
    Forest = RandomForestClassifier(random_state=0 )
    Forest.fit(X_train,Y_train)
    
    #Ada Boost Classification 
    from sklearn.ensemble import AdaBoostClassifier
    Ada = AdaBoostClassifier(random_state=0)
    Ada.fit(X_train,Y_train)
    
    #K_nearest Neighbour Classification
    from sklearn.neighbors import KNeighborsClassifier
    Knn = KNeighborsClassifier(n_neighbors=3)
    Knn.fit(X_train,Y_train)
    
    #Support Vector Machine Classification
    from sklearn.svm import SVC
    SVM = SVC(gamma='scale')
    SVM.fit(X_train,Y_train)
    
    #Naives Bayes Classification
    from sklearn.naive_bayes import GaussianNB
    Nb = GaussianNB()
    Nb.fit(X_train,Y_train)
    
    
    #printing the Score
    from sklearn.metrics import accuracy_score
    Y_prediction_Log = Log.predict(X_test)
    Y_prediction_SGD = SGD.predict(X_test)
    Y_prediction_tree = tree.predict(X_test)
    Y_prediction_Forest = Forest.predict(X_test)
    Y_prediction_Ada = Ada.predict(X_test)
    Y_prediction_Knn = Knn.predict(X_test)
    Y_prediction_SVM = SVM.predict(X_test)
    Y_prediction_NB = Nb.predict(X_test)
    
    #Printing the Classification report
    print('Accuracy Score')
    print('[0] Logistic Regression ',(accuracy_score(Y_test,Y_prediction_Log)))
    print('[1] SGD Classification ',(accuracy_score(Y_test,Y_prediction_SGD)))
    print('[2] Decision Tree Classification ',(accuracy_score(Y_test,Y_prediction_tree)))
    print('[3] Random Forest Classification ',(accuracy_score(Y_test,Y_prediction_Forest)))
    print('[4] Ada Boost Classification ',(accuracy_score(Y_test,Y_prediction_Ada)))
    print('[5] K_Nearest Neighbour ',(accuracy_score(Y_test,Y_prediction_Knn)))
    print('[6] Support Vector Machine ',(accuracy_score(Y_test,Y_prediction_SVM)))
    print('[7] Naive Bayes Classification ',(accuracy_score(Y_test,Y_prediction_NB)))
    
    
    return Log , SGD , tree ,Forest , Ada , Knn , Nb

# %%
Scores = Score(X_train,Y_train)
# Out:
# Accuracy Score
# [0] Logistic Regression  0.8775510204081632
# [1] SGD Classification  0.826530612244898
# [2] Decision Tree Classification  0.7517006802721088
# [3] Random Forest Classification  0.8537414965986394
# [4] Ada Boost Classification  0.8503401360544217
# [5] K_Nearest Neighbour  0.8197278911564626
# [6] Support Vector Machine  0.8571428571428571
# [7] Naive Bayes Classification  0.7959183673469388

# %%
def Classification_report(X_train,Y_train):
    #Logistic Regression 
    from sklearn.linear_model import LogisticRegression
    Log = LogisticRegression(random_state=0,solver='lbfgs')
    Log.fit(X_train,Y_train)
    
    #SGD Classification
    from sklearn.linear_model import SGDClassifier
    SGD = SGDClassifier(random_state=0)
    SGD.fit(X_train,Y_train)
    
    #Decision Tree Classification
    from sklearn.tree import DecisionTreeClassifier
    tree = DecisionTreeClassifier(random_state=0)
    tree.fit(X_train,Y_train)
    
    #Random Forest Classification
    from sklearn.ensemble import RandomForestClassifier
    Forest = RandomForestClassifier(random_state=0 )
    Forest.fit(X_train,Y_train)
    
    #Ada Boost Classification 
    from sklearn.ensemble import AdaBoostClassifier
    Ada = AdaBoostClassifier(random_state=0)
    Ada.fit(X_train,Y_train)
    
    #K_nearest Neighbour Classification
    from sklearn.neighbors import KNeighborsClassifier
    Knn = KNeighborsClassifier(n_neighbors=3)
    Knn.fit(X_train,Y_train)
    
    #Support Vector Machine Classification
    from sklearn.svm import SVC
    SVM = SVC(gamma='scale')
    SVM.fit(X_train,Y_train)
    
    #Naives Bayes Classification
    from sklearn.naive_bayes import GaussianNB
    Nb = GaussianNB()
    Nb.fit(X_train,Y_train)
    
    #printing the Classification Report 
    from sklearn.metrics import classification_report

    print('Classification Reports')
    Y_prediction_Log = Models[0].predict(X_test)
    print('Logistic Regression')
    print(classification_report(Y_test,Y_prediction_Log))
    
    print('SGD Classification')
    Y_prediction_SGD = Models[1].predict(X_test)
    print(classification_report(Y_test,Y_prediction_SGD))
    
    print('Decision tree Classification')
    Y_prediction_tree = Models[2].predict(X_test)
    print(classification_report(Y_test,Y_prediction_tree))
    
    print('Random Forest Classification')
    Y_prediction_Forest = Models[3].predict(X_test)
    print(classification_report(Y_test,Y_prediction_Forest))
    
    print('Ada Boost Classification')
    Y_prediction_ada = Models[4].predict(X_test)
    print(classification_report(Y_test,Y_prediction_ada))
    
    print('K Nearest Neighbour Classification')
    Y_prediction_Knn = Models[5].predict(X_test)
    print(classification_report(Y_test,Y_prediction_Knn))
    
    print('Support Vector Machine Classification')
    Y_prediction_SVM = Models[6].predict(X_test)
    print(classification_report(Y_test,Y_prediction_SVM))
    
    print('Naive Bayes Classification')
    Y_prediction_Nb = Models[7].predict(X_test)
    print(classification_report(Y_test,Y_prediction_Nb))
    
    
    return Log , SGD , tree , Forest , Ada , Knn , SVM , Nb

# %%
c = Classification_report(X_train,Y_train)
# Out:
# Classification Reports
# Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93       245
#            1       0.76      0.39      0.51        49
#
#     accuracy                           0.88       294
#    macro avg       0.82      0.68      0.72       294
# weighted avg       0.87      0.88      0.86       294
#
# SGD Classification
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.89       245
#            1       0.48      0.55      0.51        49
#
#     accuracy                           0.83       294
#    macro avg       0.69      0.72      0.70       294
# weighted avg       0.84      0.83      0.83       294
#
# Decision tree Classification
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.85       245
#            1       0.29      0.35      0.32        49
#
# ...
